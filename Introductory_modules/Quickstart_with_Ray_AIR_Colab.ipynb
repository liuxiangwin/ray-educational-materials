# %% [markdown]
# # Quickstart with Ray AI Runtime
#
# <img src="https://technical-training-assets.s3.us-west-2.amazonaws.com/Generic/ray_logo.png" width="20%" loading="lazy">

# %% [markdown]
# ## Preliminaries

# %% [markdown]
# ### Install libraries

# %%
#! pip install -U ray==2.3.0 xgboost_ray==0.1.18 --quiet
! pip install xgboost_ray==0.1.18 --quiet
# Out:
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Imports

# %%
import ray
from ray.air.config import ScalingConfig
from ray.data.preprocessors import MinMaxScaler
from ray.train.xgboost import XGBoostTrainer

# %% [markdown]
# ### Initialize Ray runtime

# %%
# Import pieces from codeflare-sdk
# !pip install -U scikit-learn scipy matplotlib --quiet

# !pip install scikit-learn
# !pip install datasets  --quiet
from codeflare_sdk import Cluster, ClusterConfiguration, TokenAuthentication
# Out:
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Create authentication object for user permissions
# IF unused, SDK will automatically check for default kubeconfig, then in-cluster config
# KubeConfigFileAuthentication can also be used to specify kubeconfig path manually
auth_token = "sha256~GgywL5jjJJSuqlWtu9DIDTpH2YEEAeI-lSDuJdMlQbU" # The auth_token is used later for the RayJobClient
auth = TokenAuthentication(
    token = auth_token,
    server = "https://api.cluster-98dpx.sandbox1573.opentlc.com:6443",
    skip_tls = False
)
auth.login()
# Out:
# 'Logged into https://api.cluster-98dpx.sandbox1573.opentlc.com:6443'

# %%
# Create and configure our cluster object (and appwrapper)
cluster = Cluster(ClusterConfiguration(
    name='quickstart-ray-air',
    namespace='ray-distributed-workload',
    num_workers=2,
    min_cpus=8,
    max_cpus=8,
    min_memory=16,
    max_memory=16,
    num_gpus=2,
    image="quay.io/project-codeflare/ray:latest-py39-cu118",
    instascale=False, #<---instascale enabled
    # machine_types=["m5.xlarge", "g4dn.xlarge"]
    # machine_types=["m5.2xlarge", "g5.2xlarge"],
    openshift_oauth=True
))
# Out:
# Written to: /opt/app-root/src/.codeflare/appwrapper/quickstart-ray-air.yaml

# %%
cluster.up()
cluster.status()
cluster.wait_ready()
cluster.status()
cluster.details()
# Out:
# ╭───────────────────────────────────╮
# │     🚀 Cluster Queue Status 🚀    │
# │ +--------------------+----------+ │
# │ | Name               | Status   | │
# │ +====================+==========+ │
# │ | quickstart-ray-air | queueing | │
# │ |                    |          | │
# │ +--------------------+----------+ │
# ╰───────────────────────────────────╯
# Waiting for requested resources to be set up...
# Requested cluster is up and running!
# Dashboard is ready!
# /opt/app-root/lib64/python3.9/site-packages/urllib3/connectionpool.py:1061: InsecureRequestWarning: Unverified HTTPS request is being made to host 'ray-dashboard-quickstart-ray-air-ray-distributed-workload.apps.cluster-98dpx.sandbox1573.opentlc.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                                 🚀 CodeFlare Cluster Status 🚀
#
#  ╭──────────────────────────────────────────────────────────────────────────────────────────╮
#  │   Name                                                                                   │
#  │   quickstart-ray-air                                                         Active ✅   │
#  │                                                                                          │
#  │   URI: ray://quickstart-ray-air-head-svc.ray-distributed-workload.svc:10001              │
#  │                                                                                          │
#  │   ]8;id=181873;https://ray-dashboard-quickstart-ray-air-ray-distributed-workload.apps.cluster-98dpx.sandbox1573.opentlc.com\Dashboard🔗]8;;\                                                                            │
#  │                                                                                          │
#  ╰──────────────────────────────────────────────────────────────────────────────────────────╯
#                                 🚀 CodeFlare Cluster Details 🚀
#
#  ╭──────────────────────────────────────────────────────────────────────────────────────────╮
#  │   Name                                                                                   │
#  │   quickstart-ray-air                                                         Active ✅   │
#  │                                                                                          │
#  │   URI: ray://quickstart-ray-air-head-svc.ray-distributed-workload.svc:10001              │
#  │                                                                                          │
#  │   ]8;id=416831;https://ray-dashboard-quickstart-ray-air-ray-distributed-workload.apps.cluster-98dpx.sandbox1573.opentlc.com\Dashboard🔗]8;;\                                                                            │
#  │                                                                                          │
#  │                       Cluster Resources                                                  │
#  │   ╭── Workers ──╮  ╭───────── Worker specs(each) ─────────╮                              │
#  │   │  # Workers  │  │  Memory      CPU         GPU         │                              │
#  │   │             │  │                                      │                              │
#  │   │  2          │  │  16~16       8           2           │                              │
#  │   │             │  │                                      │                              │
#  │   ╰─────────────╯  ╰──────────────────────────────────────╯                              │
#  ╰──────────────────────────────────────────────────────────────────────────────────────────╯
# RayCluster(name='quickstart-ray-air', status=<RayClusterStatus.READY: 'ready'>, head_cpus=2, head_mem=8, head_gpu=0, workers=2, worker_mem_min=16, worker_mem_max=16, worker_cpu=8, worker_gpu=2, namespace='ray-distributed-workload', dashboard='https://ray-dashboard-quickstart-ray-air-ray-distributed-workload.apps.cluster-98dpx.sandbox1573.opentlc.com')

# %%
ray_dashboard_uri = cluster.cluster_dashboard_uri()
ray_cluster_uri = cluster.cluster_uri()
print(ray_dashboard_uri)
print(ray_cluster_uri)
# Out:
# https://ray-dashboard-quickstart-ray-air-ray-distributed-workload.apps.cluster-98dpx.sandbox1573.opentlc.com
# ray://quickstart-ray-air-head-svc.ray-distributed-workload.svc:10001

# %%
#before proceeding make sure the cluster exists and the uri is not empty
# assert ray_cluster_uri, "Ray cluster needs to be started and set before proceeding"

import ray
from ray.air.config import ScalingConfig

# reset the ray context in case there's already one. 
ray.shutdown()
# establish connection to ray cluster

#install additional libraries that will be required for model training
runtime_env = {"pip": ["transformers", "datasets", "evaluate", "pyarrow<7.0.0", "ipython","xgboost_ray","accelerate"]}

# NOTE: This will work for in-cluster notebook servers (RHODS/ODH), but not for local machines
# To see how to connect from your laptop, go to demo-notebooks/additional-demos/local_interactive.ipynb
ray.init(address=ray_cluster_uri, runtime_env=runtime_env)

print("Ray cluster is up and running: ", ray.is_initialized())
# Out:
# Ray cluster is up and running:  True
# (TunerInternal pid=1180) [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) View detailed results here: /home/ray/ray_results/XGBoostTrainer_2024-04-13_03-14-51
# (TunerInternal pid=1180) To visualize your results with TensorBoard, run: `tensorboard --logdir /home/ray/ray_results/XGBoostTrainer_2024-04-13_03-14-51`
# (TunerInternal pid=1180) AIR_VERBOSITY is set, ignoring passed-in ProgressReporter for now.
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training started without custom configuration.
# (XGBoostTrainer pid=1311) /tmp/ray/session_2024-04-13_03-10-59_741009_8/runtime_resources/pip/61b02e24503ca48f6f27550313b2d501029b25cd/virtualenv/lib/python3.9/site-packages/xgboost_ray/main.py:1501: UserWarning: GPUs have been assigned to the actors, but the current XGBoost tree method is set to `approx`. Thus, GPUs will currently not be used. To enable GPUs usage, please set the `tree_method` to a GPU-compatible option, e.g. `gpu_hist`.
# (XGBoostTrainer pid=1311)   warnings.warn(
# (XGBoostTrainer pid=1311) [RayXGBoost] Created 2 new actors (2 total actors). Waiting until actors are ready for training.
# (XGBoostTrainer pid=1311) Executing DAG InputDataBuffer[Input] -> AllToAllOperator[Repartition]
# (XGBoostTrainer pid=1311) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (XGBoostTrainer pid=1311) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (XGBoostTrainer pid=1311) Executing DAG InputDataBuffer[Input] -> AllToAllOperator[Repartition]
# (XGBoostTrainer pid=1311) Execution config: ExecutionOptions(resource_limits=ExecutionResources(cpu=None, gpu=None, object_store_memory=None), locality_with_output=False, preserve_order=False, actor_locality_enabled=True, verbose_progress=False)
# (XGBoostTrainer pid=1311) Tip: For detailed progress reporting, run `ray.data.DataContext.get_current().execution_options.verbose_progress = True`
# (XGBoostTrainer pid=1311) [RayXGBoost] Starting XGBoost training.
# (_RemoteRayXGBoostActor pid=370, ip=10.131.2.84) [03:14:59] task [xgboost.ray]:139623051234704 got new rank 0
# (_RemoteRayXGBoostActor pid=371, ip=10.131.2.84) [03:14:59] task [xgboost.ray]:139807743453696 got new rank 1
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 1 at 2024-04-13 03:15:02. Total running time: 7s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      6.42428 │
# (TunerInternal pid=1180) │ time_total_s          6.42428 │
# (TunerInternal pid=1180) │ training_iteration          1 │
# (TunerInternal pid=1180) │ train-error           0.39698 │
# (TunerInternal pid=1180) │ train-logloss         0.66884 │
# (TunerInternal pid=1180) │ valid-error           0.39574 │
# (TunerInternal pid=1180) │ valid-logloss         0.66836 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 2 at 2024-04-13 03:15:02. Total running time: 7s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00846 │
# (TunerInternal pid=1180) │ time_total_s          6.43273 │
# (TunerInternal pid=1180) │ training_iteration          2 │
# (TunerInternal pid=1180) │ train-error           0.39492 │
# (TunerInternal pid=1180) │ train-logloss          0.6653 │
# (TunerInternal pid=1180) │ valid-error           0.39381 │
# (TunerInternal pid=1180) │ valid-logloss          0.6651 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 3 at 2024-04-13 03:15:02. Total running time: 7s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       0.0045 │
# (TunerInternal pid=1180) │ time_total_s          6.43723 │
# (TunerInternal pid=1180) │ training_iteration          3 │
# (TunerInternal pid=1180) │ train-error            0.3942 │
# (TunerInternal pid=1180) │ train-logloss         0.66334 │
# (TunerInternal pid=1180) │ valid-error           0.39317 │
# (TunerInternal pid=1180) │ valid-logloss         0.66333 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 4 at 2024-04-13 03:15:03. Total running time: 9s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.00792 │
# (TunerInternal pid=1180) │ time_total_s          7.44515 │
# (TunerInternal pid=1180) │ training_iteration          4 │
# (TunerInternal pid=1180) │ train-error            0.3936 │
# (TunerInternal pid=1180) │ train-logloss         0.66216 │
# (TunerInternal pid=1180) │ valid-error           0.39265 │
# (TunerInternal pid=1180) │ valid-logloss          0.6623 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 5 at 2024-04-13 03:15:03. Total running time: 9s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00476 │
# (TunerInternal pid=1180) │ time_total_s          7.44991 │
# (TunerInternal pid=1180) │ training_iteration          5 │
# (TunerInternal pid=1180) │ train-error           0.39251 │
# (TunerInternal pid=1180) │ train-logloss         0.66144 │
# (TunerInternal pid=1180) │ valid-error           0.39155 │
# (TunerInternal pid=1180) │ valid-logloss         0.66167 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 6 at 2024-04-13 03:15:04. Total running time: 10s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       1.0085 │
# (TunerInternal pid=1180) │ time_total_s           8.4584 │
# (TunerInternal pid=1180) │ training_iteration          6 │
# (TunerInternal pid=1180) │ train-error           0.39217 │
# (TunerInternal pid=1180) │ train-logloss          0.6609 │
# (TunerInternal pid=1180) │ valid-error           0.39129 │
# (TunerInternal pid=1180) │ valid-logloss         0.66123 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 7 at 2024-04-13 03:15:04. Total running time: 10s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00797 │
# (TunerInternal pid=1180) │ time_total_s          8.46637 │
# (TunerInternal pid=1180) │ training_iteration          7 │
# (TunerInternal pid=1180) │ train-error           0.39177 │
# (TunerInternal pid=1180) │ train-logloss         0.66045 │
# (TunerInternal pid=1180) │ valid-error           0.39107 │
# (TunerInternal pid=1180) │ valid-logloss         0.66087 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 8 at 2024-04-13 03:15:05. Total running time: 11s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.00876 │
# (TunerInternal pid=1180) │ time_total_s          9.47513 │
# (TunerInternal pid=1180) │ training_iteration          8 │
# (TunerInternal pid=1180) │ train-error           0.39149 │
# (TunerInternal pid=1180) │ train-logloss         0.66011 │
# (TunerInternal pid=1180) │ valid-error           0.39084 │
# (TunerInternal pid=1180) │ valid-logloss          0.6606 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 9 at 2024-04-13 03:15:05. Total running time: 11s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00562 │
# (TunerInternal pid=1180) │ time_total_s          9.48075 │
# (TunerInternal pid=1180) │ training_iteration          9 │
# (TunerInternal pid=1180) │ train-error           0.39095 │
# (TunerInternal pid=1180) │ train-logloss         0.65978 │
# (TunerInternal pid=1180) │ valid-error           0.39063 │
# (TunerInternal pid=1180) │ valid-logloss         0.66034 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 10 at 2024-04-13 03:15:06. Total running time: 12s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.00835 │
# (TunerInternal pid=1180) │ time_total_s          10.4891 │
# (TunerInternal pid=1180) │ training_iteration         10 │
# (TunerInternal pid=1180) │ train-error           0.39076 │
# (TunerInternal pid=1180) │ train-logloss         0.65958 │
# (TunerInternal pid=1180) │ valid-error            0.3905 │
# (TunerInternal pid=1180) │ valid-logloss         0.66021 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 11 at 2024-04-13 03:15:06. Total running time: 12s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00504 │
# (TunerInternal pid=1180) │ time_total_s          10.4941 │
# (TunerInternal pid=1180) │ training_iteration         11 │
# (TunerInternal pid=1180) │ train-error           0.39054 │
# (TunerInternal pid=1180) │ train-logloss         0.65935 │
# (TunerInternal pid=1180) │ valid-error           0.39047 │
# (TunerInternal pid=1180) │ valid-logloss         0.66006 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 12 at 2024-04-13 03:15:06. Total running time: 12s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00751 │
# (TunerInternal pid=1180) │ time_total_s          10.5016 │
# (TunerInternal pid=1180) │ training_iteration         12 │
# (TunerInternal pid=1180) │ train-error           0.39056 │
# (TunerInternal pid=1180) │ train-logloss         0.65925 │
# (TunerInternal pid=1180) │ valid-error           0.39048 │
# (TunerInternal pid=1180) │ valid-logloss         0.66001 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 13 at 2024-04-13 03:15:07. Total running time: 13s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.00872 │
# (TunerInternal pid=1180) │ time_total_s          11.5104 │
# (TunerInternal pid=1180) │ training_iteration         13 │
# (TunerInternal pid=1180) │ train-error           0.39039 │
# (TunerInternal pid=1180) │ train-logloss         0.65914 │
# (TunerInternal pid=1180) │ valid-error           0.39043 │
# (TunerInternal pid=1180) │ valid-logloss         0.65992 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 14 at 2024-04-13 03:15:07. Total running time: 13s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00493 │
# (TunerInternal pid=1180) │ time_total_s          11.5153 │
# (TunerInternal pid=1180) │ training_iteration         14 │
# (TunerInternal pid=1180) │ train-error           0.39006 │
# (TunerInternal pid=1180) │ train-logloss         0.65893 │
# (TunerInternal pid=1180) │ valid-error            0.3902 │
# (TunerInternal pid=1180) │ valid-logloss         0.65976 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 15 at 2024-04-13 03:15:08. Total running time: 14s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.00925 │
# (TunerInternal pid=1180) │ time_total_s          12.5245 │
# (TunerInternal pid=1180) │ training_iteration         15 │
# (TunerInternal pid=1180) │ train-error           0.38976 │
# (TunerInternal pid=1180) │ train-logloss         0.65878 │
# (TunerInternal pid=1180) │ valid-error           0.38984 │
# (TunerInternal pid=1180) │ valid-logloss         0.65965 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 16 at 2024-04-13 03:15:08. Total running time: 14s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       0.0051 │
# (TunerInternal pid=1180) │ time_total_s          12.5296 │
# (TunerInternal pid=1180) │ training_iteration         16 │
# (TunerInternal pid=1180) │ train-error           0.38956 │
# (TunerInternal pid=1180) │ train-logloss          0.6586 │
# (TunerInternal pid=1180) │ valid-error           0.38974 │
# (TunerInternal pid=1180) │ valid-logloss         0.65952 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 17 at 2024-04-13 03:15:09. Total running time: 15s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01103 │
# (TunerInternal pid=1180) │ time_total_s          13.5407 │
# (TunerInternal pid=1180) │ training_iteration         17 │
# (TunerInternal pid=1180) │ train-error           0.38957 │
# (TunerInternal pid=1180) │ train-logloss         0.65855 │
# (TunerInternal pid=1180) │ valid-error           0.38967 │
# (TunerInternal pid=1180) │ valid-logloss         0.65949 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 18 at 2024-04-13 03:15:09. Total running time: 15s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00489 │
# (TunerInternal pid=1180) │ time_total_s          13.5456 │
# (TunerInternal pid=1180) │ training_iteration         18 │
# (TunerInternal pid=1180) │ train-error           0.38929 │
# (TunerInternal pid=1180) │ train-logloss         0.65838 │
# (TunerInternal pid=1180) │ valid-error            0.3896 │
# (TunerInternal pid=1180) │ valid-logloss         0.65938 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 19 at 2024-04-13 03:15:10. Total running time: 16s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.00882 │
# (TunerInternal pid=1180) │ time_total_s          14.5544 │
# (TunerInternal pid=1180) │ training_iteration         19 │
# (TunerInternal pid=1180) │ train-error            0.3892 │
# (TunerInternal pid=1180) │ train-logloss         0.65829 │
# (TunerInternal pid=1180) │ valid-error           0.38951 │
# (TunerInternal pid=1180) │ valid-logloss         0.65932 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 20 at 2024-04-13 03:15:10. Total running time: 16s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00496 │
# (TunerInternal pid=1180) │ time_total_s          14.5594 │
# (TunerInternal pid=1180) │ training_iteration         20 │
# (TunerInternal pid=1180) │ train-error           0.38898 │
# (TunerInternal pid=1180) │ train-logloss         0.65817 │
# (TunerInternal pid=1180) │ valid-error           0.38942 │
# (TunerInternal pid=1180) │ valid-logloss         0.65923 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 21 at 2024-04-13 03:15:11. Total running time: 17s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       1.0121 │
# (TunerInternal pid=1180) │ time_total_s          15.5715 │
# (TunerInternal pid=1180) │ training_iteration         21 │
# (TunerInternal pid=1180) │ train-error            0.3889 │
# (TunerInternal pid=1180) │ train-logloss         0.65809 │
# (TunerInternal pid=1180) │ valid-error           0.38935 │
# (TunerInternal pid=1180) │ valid-logloss         0.65917 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 22 at 2024-04-13 03:15:11. Total running time: 17s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01111 │
# (TunerInternal pid=1180) │ time_total_s          15.5826 │
# (TunerInternal pid=1180) │ training_iteration         22 │
# (TunerInternal pid=1180) │ train-error           0.38886 │
# (TunerInternal pid=1180) │ train-logloss         0.65802 │
# (TunerInternal pid=1180) │ valid-error           0.38933 │
# (TunerInternal pid=1180) │ valid-logloss         0.65914 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 23 at 2024-04-13 03:15:11. Total running time: 17s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00867 │
# (TunerInternal pid=1180) │ time_total_s          15.5912 │
# (TunerInternal pid=1180) │ training_iteration         23 │
# (TunerInternal pid=1180) │ train-error           0.38877 │
# (TunerInternal pid=1180) │ train-logloss         0.65791 │
# (TunerInternal pid=1180) │ valid-error           0.38927 │
# (TunerInternal pid=1180) │ valid-logloss         0.65907 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 24 at 2024-04-13 03:15:12. Total running time: 18s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01285 │
# (TunerInternal pid=1180) │ time_total_s          16.6041 │
# (TunerInternal pid=1180) │ training_iteration         24 │
# (TunerInternal pid=1180) │ train-error           0.38873 │
# (TunerInternal pid=1180) │ train-logloss         0.65786 │
# (TunerInternal pid=1180) │ valid-error           0.38932 │
# (TunerInternal pid=1180) │ valid-logloss         0.65905 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 25 at 2024-04-13 03:15:12. Total running time: 18s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00841 │
# (TunerInternal pid=1180) │ time_total_s          16.6125 │
# (TunerInternal pid=1180) │ training_iteration         25 │
# (TunerInternal pid=1180) │ train-error           0.38862 │
# (TunerInternal pid=1180) │ train-logloss         0.65779 │
# (TunerInternal pid=1180) │ valid-error           0.38921 │
# (TunerInternal pid=1180) │ valid-logloss           0.659 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 26 at 2024-04-13 03:15:13. Total running time: 19s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01172 │
# (TunerInternal pid=1180) │ time_total_s          17.6242 │
# (TunerInternal pid=1180) │ training_iteration         26 │
# (TunerInternal pid=1180) │ train-error           0.38847 │
# (TunerInternal pid=1180) │ train-logloss         0.65771 │
# (TunerInternal pid=1180) │ valid-error           0.38915 │
# (TunerInternal pid=1180) │ valid-logloss         0.65896 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 27 at 2024-04-13 03:15:13. Total running time: 19s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01396 │
# (TunerInternal pid=1180) │ time_total_s          17.6382 │
# (TunerInternal pid=1180) │ training_iteration         27 │
# (TunerInternal pid=1180) │ train-error           0.38833 │
# (TunerInternal pid=1180) │ train-logloss         0.65761 │
# (TunerInternal pid=1180) │ valid-error           0.38908 │
# (TunerInternal pid=1180) │ valid-logloss         0.65889 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 28 at 2024-04-13 03:15:14. Total running time: 20s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01212 │
# (TunerInternal pid=1180) │ time_total_s          18.6503 │
# (TunerInternal pid=1180) │ training_iteration         28 │
# (TunerInternal pid=1180) │ train-error           0.38828 │
# (TunerInternal pid=1180) │ train-logloss         0.65753 │
# (TunerInternal pid=1180) │ valid-error           0.38913 │
# (TunerInternal pid=1180) │ valid-logloss         0.65886 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 29 at 2024-04-13 03:15:14. Total running time: 20s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       0.0091 │
# (TunerInternal pid=1180) │ time_total_s          18.6594 │
# (TunerInternal pid=1180) │ training_iteration         29 │
# (TunerInternal pid=1180) │ train-error           0.38827 │
# (TunerInternal pid=1180) │ train-logloss          0.6575 │
# (TunerInternal pid=1180) │ valid-error           0.38909 │
# (TunerInternal pid=1180) │ valid-logloss         0.65885 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 30 at 2024-04-13 03:15:16. Total running time: 21s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       1.0123 │
# (TunerInternal pid=1180) │ time_total_s          19.6717 │
# (TunerInternal pid=1180) │ training_iteration         30 │
# (TunerInternal pid=1180) │ train-error           0.38811 │
# (TunerInternal pid=1180) │ train-logloss         0.65743 │
# (TunerInternal pid=1180) │ valid-error           0.38896 │
# (TunerInternal pid=1180) │ valid-logloss         0.65881 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 31 at 2024-04-13 03:15:16. Total running time: 21s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00769 │
# (TunerInternal pid=1180) │ time_total_s          19.6794 │
# (TunerInternal pid=1180) │ training_iteration         31 │
# (TunerInternal pid=1180) │ train-error           0.38795 │
# (TunerInternal pid=1180) │ train-logloss         0.65736 │
# (TunerInternal pid=1180) │ valid-error           0.38879 │
# (TunerInternal pid=1180) │ valid-logloss         0.65878 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 32 at 2024-04-13 03:15:17. Total running time: 22s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       1.0154 │
# (TunerInternal pid=1180) │ time_total_s          20.6948 │
# (TunerInternal pid=1180) │ training_iteration         32 │
# (TunerInternal pid=1180) │ train-error           0.38794 │
# (TunerInternal pid=1180) │ train-logloss         0.65734 │
# (TunerInternal pid=1180) │ valid-error           0.38876 │
# (TunerInternal pid=1180) │ valid-logloss         0.65877 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 33 at 2024-04-13 03:15:17. Total running time: 22s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00812 │
# (TunerInternal pid=1180) │ time_total_s          20.7029 │
# (TunerInternal pid=1180) │ training_iteration         33 │
# (TunerInternal pid=1180) │ train-error            0.3879 │
# (TunerInternal pid=1180) │ train-logloss         0.65728 │
# (TunerInternal pid=1180) │ valid-error           0.38866 │
# (TunerInternal pid=1180) │ valid-logloss         0.65875 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 34 at 2024-04-13 03:15:17. Total running time: 22s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00803 │
# (TunerInternal pid=1180) │ time_total_s           20.711 │
# (TunerInternal pid=1180) │ training_iteration         34 │
# (TunerInternal pid=1180) │ train-error           0.38785 │
# (TunerInternal pid=1180) │ train-logloss         0.65721 │
# (TunerInternal pid=1180) │ valid-error           0.38862 │
# (TunerInternal pid=1180) │ valid-logloss         0.65871 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 35 at 2024-04-13 03:15:18. Total running time: 23s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01196 │
# (TunerInternal pid=1180) │ time_total_s          21.7229 │
# (TunerInternal pid=1180) │ training_iteration         35 │
# (TunerInternal pid=1180) │ train-error           0.38775 │
# (TunerInternal pid=1180) │ train-logloss         0.65714 │
# (TunerInternal pid=1180) │ valid-error           0.38855 │
# (TunerInternal pid=1180) │ valid-logloss         0.65867 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 36 at 2024-04-13 03:15:18. Total running time: 23s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00801 │
# (TunerInternal pid=1180) │ time_total_s          21.7309 │
# (TunerInternal pid=1180) │ training_iteration         36 │
# (TunerInternal pid=1180) │ train-error           0.38774 │
# (TunerInternal pid=1180) │ train-logloss         0.65709 │
# (TunerInternal pid=1180) │ valid-error           0.38856 │
# (TunerInternal pid=1180) │ valid-logloss         0.65865 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 37 at 2024-04-13 03:15:19. Total running time: 24s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01787 │
# (TunerInternal pid=1180) │ time_total_s          22.7488 │
# (TunerInternal pid=1180) │ training_iteration         37 │
# (TunerInternal pid=1180) │ train-error           0.38767 │
# (TunerInternal pid=1180) │ train-logloss         0.65704 │
# (TunerInternal pid=1180) │ valid-error           0.38849 │
# (TunerInternal pid=1180) │ valid-logloss         0.65864 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 38 at 2024-04-13 03:15:19. Total running time: 24s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00963 │
# (TunerInternal pid=1180) │ time_total_s          22.7584 │
# (TunerInternal pid=1180) │ training_iteration         38 │
# (TunerInternal pid=1180) │ train-error           0.38758 │
# (TunerInternal pid=1180) │ train-logloss         0.65696 │
# (TunerInternal pid=1180) │ valid-error           0.38847 │
# (TunerInternal pid=1180) │ valid-logloss         0.65862 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 39 at 2024-04-13 03:15:20. Total running time: 25s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01273 │
# (TunerInternal pid=1180) │ time_total_s          23.7712 │
# (TunerInternal pid=1180) │ training_iteration         39 │
# (TunerInternal pid=1180) │ train-error           0.38754 │
# (TunerInternal pid=1180) │ train-logloss         0.65692 │
# (TunerInternal pid=1180) │ valid-error           0.38841 │
# (TunerInternal pid=1180) │ valid-logloss         0.65861 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 40 at 2024-04-13 03:15:20. Total running time: 25s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00874 │
# (TunerInternal pid=1180) │ time_total_s          23.7799 │
# (TunerInternal pid=1180) │ training_iteration         40 │
# (TunerInternal pid=1180) │ train-error           0.38743 │
# (TunerInternal pid=1180) │ train-logloss         0.65687 │
# (TunerInternal pid=1180) │ valid-error           0.38834 │
# (TunerInternal pid=1180) │ valid-logloss         0.65858 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 41 at 2024-04-13 03:15:21. Total running time: 26s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       1.0132 │
# (TunerInternal pid=1180) │ time_total_s          24.7931 │
# (TunerInternal pid=1180) │ training_iteration         41 │
# (TunerInternal pid=1180) │ train-error           0.38738 │
# (TunerInternal pid=1180) │ train-logloss         0.65683 │
# (TunerInternal pid=1180) │ valid-error           0.38833 │
# (TunerInternal pid=1180) │ valid-logloss         0.65857 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 42 at 2024-04-13 03:15:21. Total running time: 26s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01509 │
# (TunerInternal pid=1180) │ time_total_s          24.8082 │
# (TunerInternal pid=1180) │ training_iteration         42 │
# (TunerInternal pid=1180) │ train-error           0.38732 │
# (TunerInternal pid=1180) │ train-logloss          0.6568 │
# (TunerInternal pid=1180) │ valid-error           0.38833 │
# (TunerInternal pid=1180) │ valid-logloss         0.65857 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 43 at 2024-04-13 03:15:21. Total running time: 26s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00927 │
# (TunerInternal pid=1180) │ time_total_s          24.8175 │
# (TunerInternal pid=1180) │ training_iteration         43 │
# (TunerInternal pid=1180) │ train-error           0.38724 │
# (TunerInternal pid=1180) │ train-logloss         0.65674 │
# (TunerInternal pid=1180) │ valid-error           0.38834 │
# (TunerInternal pid=1180) │ valid-logloss         0.65856 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 44 at 2024-04-13 03:15:22. Total running time: 27s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       1.0122 │
# (TunerInternal pid=1180) │ time_total_s          25.8297 │
# (TunerInternal pid=1180) │ training_iteration         44 │
# (TunerInternal pid=1180) │ train-error            0.3872 │
# (TunerInternal pid=1180) │ train-logloss         0.65671 │
# (TunerInternal pid=1180) │ valid-error            0.3883 │
# (TunerInternal pid=1180) │ valid-logloss         0.65856 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 45 at 2024-04-13 03:15:22. Total running time: 27s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00795 │
# (TunerInternal pid=1180) │ time_total_s          25.8376 │
# (TunerInternal pid=1180) │ training_iteration         45 │
# (TunerInternal pid=1180) │ train-error           0.38716 │
# (TunerInternal pid=1180) │ train-logloss         0.65666 │
# (TunerInternal pid=1180) │ valid-error           0.38829 │
# (TunerInternal pid=1180) │ valid-logloss         0.65854 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 46 at 2024-04-13 03:15:23. Total running time: 28s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       1.0134 │
# (TunerInternal pid=1180) │ time_total_s           26.851 │
# (TunerInternal pid=1180) │ training_iteration         46 │
# (TunerInternal pid=1180) │ train-error           0.38706 │
# (TunerInternal pid=1180) │ train-logloss         0.65661 │
# (TunerInternal pid=1180) │ valid-error           0.38826 │
# (TunerInternal pid=1180) │ valid-logloss         0.65853 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 47 at 2024-04-13 03:15:23. Total running time: 28s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01527 │
# (TunerInternal pid=1180) │ time_total_s          26.8663 │
# (TunerInternal pid=1180) │ training_iteration         47 │
# (TunerInternal pid=1180) │ train-error           0.38705 │
# (TunerInternal pid=1180) │ train-logloss         0.65658 │
# (TunerInternal pid=1180) │ valid-error           0.38826 │
# (TunerInternal pid=1180) │ valid-logloss         0.65854 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 48 at 2024-04-13 03:15:24. Total running time: 29s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01218 │
# (TunerInternal pid=1180) │ time_total_s          27.8785 │
# (TunerInternal pid=1180) │ training_iteration         48 │
# (TunerInternal pid=1180) │ train-error           0.38701 │
# (TunerInternal pid=1180) │ train-logloss         0.65654 │
# (TunerInternal pid=1180) │ valid-error           0.38829 │
# (TunerInternal pid=1180) │ valid-logloss         0.65853 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 49 at 2024-04-13 03:15:24. Total running time: 29s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00821 │
# (TunerInternal pid=1180) │ time_total_s          27.8867 │
# (TunerInternal pid=1180) │ training_iteration         49 │
# (TunerInternal pid=1180) │ train-error           0.38697 │
# (TunerInternal pid=1180) │ train-logloss          0.6565 │
# (TunerInternal pid=1180) │ valid-error           0.38826 │
# (TunerInternal pid=1180) │ valid-logloss         0.65852 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 50 at 2024-04-13 03:15:25. Total running time: 30s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01244 │
# (TunerInternal pid=1180) │ time_total_s          28.8991 │
# (TunerInternal pid=1180) │ training_iteration         50 │
# (TunerInternal pid=1180) │ train-error           0.38694 │
# (TunerInternal pid=1180) │ train-logloss         0.65644 │
# (TunerInternal pid=1180) │ valid-error           0.38821 │
# (TunerInternal pid=1180) │ valid-logloss         0.65849 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 51 at 2024-04-13 03:15:25. Total running time: 30s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01031 │
# (TunerInternal pid=1180) │ time_total_s          28.9094 │
# (TunerInternal pid=1180) │ training_iteration         51 │
# (TunerInternal pid=1180) │ train-error           0.38687 │
# (TunerInternal pid=1180) │ train-logloss         0.65641 │
# (TunerInternal pid=1180) │ valid-error           0.38829 │
# (TunerInternal pid=1180) │ valid-logloss         0.65849 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 52 at 2024-04-13 03:15:25. Total running time: 30s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       0.0157 │
# (TunerInternal pid=1180) │ time_total_s          28.9251 │
# (TunerInternal pid=1180) │ training_iteration         52 │
# (TunerInternal pid=1180) │ train-error           0.38684 │
# (TunerInternal pid=1180) │ train-logloss         0.65637 │
# (TunerInternal pid=1180) │ valid-error           0.38825 │
# (TunerInternal pid=1180) │ valid-logloss         0.65849 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 53 at 2024-04-13 03:15:26. Total running time: 31s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01285 │
# (TunerInternal pid=1180) │ time_total_s           29.938 │
# (TunerInternal pid=1180) │ training_iteration         53 │
# (TunerInternal pid=1180) │ train-error           0.38677 │
# (TunerInternal pid=1180) │ train-logloss         0.65634 │
# (TunerInternal pid=1180) │ valid-error           0.38823 │
# (TunerInternal pid=1180) │ valid-logloss         0.65849 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 54 at 2024-04-13 03:15:26. Total running time: 31s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.00912 │
# (TunerInternal pid=1180) │ time_total_s          29.9471 │
# (TunerInternal pid=1180) │ training_iteration         54 │
# (TunerInternal pid=1180) │ train-error           0.38673 │
# (TunerInternal pid=1180) │ train-logloss          0.6563 │
# (TunerInternal pid=1180) │ valid-error           0.38824 │
# (TunerInternal pid=1180) │ valid-logloss         0.65849 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# ...
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 84 at 2024-04-13 03:15:40. Total running time: 46s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01406 │
# (TunerInternal pid=1180) │ time_total_s          44.3333 │
# (TunerInternal pid=1180) │ training_iteration         84 │
# (TunerInternal pid=1180) │ train-error           0.38542 │
# (TunerInternal pid=1180) │ train-logloss         0.65526 │
# (TunerInternal pid=1180) │ valid-error           0.38833 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 85 at 2024-04-13 03:15:40. Total running time: 46s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       0.0103 │
# (TunerInternal pid=1180) │ time_total_s          44.3436 │
# (TunerInternal pid=1180) │ training_iteration         85 │
# (TunerInternal pid=1180) │ train-error           0.38536 │
# (TunerInternal pid=1180) │ train-logloss         0.65523 │
# (TunerInternal pid=1180) │ valid-error           0.38829 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 86 at 2024-04-13 03:15:41. Total running time: 47s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01488 │
# (TunerInternal pid=1180) │ time_total_s          45.3585 │
# (TunerInternal pid=1180) │ training_iteration         86 │
# (TunerInternal pid=1180) │ train-error           0.38534 │
# (TunerInternal pid=1180) │ train-logloss          0.6552 │
# (TunerInternal pid=1180) │ valid-error           0.38835 │
# (TunerInternal pid=1180) │ valid-logloss         0.65844 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 87 at 2024-04-13 03:15:41. Total running time: 47s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01511 │
# (TunerInternal pid=1180) │ time_total_s          45.3736 │
# (TunerInternal pid=1180) │ training_iteration         87 │
# (TunerInternal pid=1180) │ train-error           0.38524 │
# (TunerInternal pid=1180) │ train-logloss         0.65516 │
# (TunerInternal pid=1180) │ valid-error           0.38828 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 88 at 2024-04-13 03:15:42. Total running time: 48s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s       1.0154 │
# (TunerInternal pid=1180) │ time_total_s           46.389 │
# (TunerInternal pid=1180) │ training_iteration         88 │
# (TunerInternal pid=1180) │ train-error           0.38516 │
# (TunerInternal pid=1180) │ train-logloss         0.65512 │
# (TunerInternal pid=1180) │ valid-error           0.38829 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 89 at 2024-04-13 03:15:42. Total running time: 48s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01168 │
# (TunerInternal pid=1180) │ time_total_s          46.4007 │
# (TunerInternal pid=1180) │ training_iteration         89 │
# (TunerInternal pid=1180) │ train-error           0.38512 │
# (TunerInternal pid=1180) │ train-logloss         0.65509 │
# (TunerInternal pid=1180) │ valid-error           0.38831 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 90 at 2024-04-13 03:15:42. Total running time: 48s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01122 │
# (TunerInternal pid=1180) │ time_total_s          46.4119 │
# (TunerInternal pid=1180) │ training_iteration         90 │
# (TunerInternal pid=1180) │ train-error           0.38506 │
# (TunerInternal pid=1180) │ train-logloss         0.65505 │
# (TunerInternal pid=1180) │ valid-error           0.38834 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 91 at 2024-04-13 03:15:43. Total running time: 49s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01453 │
# (TunerInternal pid=1180) │ time_total_s          47.4265 │
# (TunerInternal pid=1180) │ training_iteration         91 │
# (TunerInternal pid=1180) │ train-error           0.38498 │
# (TunerInternal pid=1180) │ train-logloss         0.65502 │
# (TunerInternal pid=1180) │ valid-error           0.38829 │
# (TunerInternal pid=1180) │ valid-logloss         0.65844 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 92 at 2024-04-13 03:15:43. Total running time: 49s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01599 │
# (TunerInternal pid=1180) │ time_total_s          47.4425 │
# (TunerInternal pid=1180) │ training_iteration         92 │
# (TunerInternal pid=1180) │ train-error           0.38493 │
# (TunerInternal pid=1180) │ train-logloss         0.65499 │
# (TunerInternal pid=1180) │ valid-error           0.38832 │
# (TunerInternal pid=1180) │ valid-logloss         0.65844 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 93 at 2024-04-13 03:15:44. Total running time: 50s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01612 │
# (TunerInternal pid=1180) │ time_total_s          48.4586 │
# (TunerInternal pid=1180) │ training_iteration         93 │
# (TunerInternal pid=1180) │ train-error            0.3849 │
# (TunerInternal pid=1180) │ train-logloss         0.65497 │
# (TunerInternal pid=1180) │ valid-error           0.38833 │
# (TunerInternal pid=1180) │ valid-logloss         0.65844 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 94 at 2024-04-13 03:15:44. Total running time: 50s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01177 │
# (TunerInternal pid=1180) │ time_total_s          48.4703 │
# (TunerInternal pid=1180) │ training_iteration         94 │
# (TunerInternal pid=1180) │ train-error           0.38489 │
# (TunerInternal pid=1180) │ train-logloss         0.65496 │
# (TunerInternal pid=1180) │ valid-error           0.38835 │
# (TunerInternal pid=1180) │ valid-logloss         0.65844 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 95 at 2024-04-13 03:15:46. Total running time: 51s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.01579 │
# (TunerInternal pid=1180) │ time_total_s          49.4861 │
# (TunerInternal pid=1180) │ training_iteration         95 │
# (TunerInternal pid=1180) │ train-error           0.38484 │
# (TunerInternal pid=1180) │ train-logloss         0.65493 │
# (TunerInternal pid=1180) │ valid-error           0.38834 │
# (TunerInternal pid=1180) │ valid-logloss         0.65844 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 96 at 2024-04-13 03:15:46. Total running time: 51s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01137 │
# (TunerInternal pid=1180) │ time_total_s          49.4975 │
# (TunerInternal pid=1180) │ training_iteration         96 │
# (TunerInternal pid=1180) │ train-error           0.38478 │
# (TunerInternal pid=1180) │ train-logloss          0.6549 │
# (TunerInternal pid=1180) │ valid-error           0.38833 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 97 at 2024-04-13 03:15:47. Total running time: 52s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      1.02548 │
# (TunerInternal pid=1180) │ time_total_s           50.523 │
# (TunerInternal pid=1180) │ training_iteration         97 │
# (TunerInternal pid=1180) │ train-error           0.38473 │
# (TunerInternal pid=1180) │ train-logloss         0.65487 │
# (TunerInternal pid=1180) │ valid-error           0.38832 │
# (TunerInternal pid=1180) │ valid-logloss         0.65844 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 98 at 2024-04-13 03:15:47. Total running time: 52s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01294 │
# (TunerInternal pid=1180) │ time_total_s          50.5359 │
# (TunerInternal pid=1180) │ training_iteration         98 │
# (TunerInternal pid=1180) │ train-error            0.3847 │
# (TunerInternal pid=1180) │ train-logloss         0.65484 │
# (TunerInternal pid=1180) │ valid-error           0.38831 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 99 at 2024-04-13 03:15:47. Total running time: 52s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.01169 │
# (TunerInternal pid=1180) │ time_total_s          50.5476 │
# (TunerInternal pid=1180) │ training_iteration         99 │
# (TunerInternal pid=1180) │ train-error           0.38468 │
# (TunerInternal pid=1180) │ train-logloss         0.65482 │
# (TunerInternal pid=1180) │ valid-error           0.38831 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 100 at 2024-04-13 03:15:47. Total running time: 52s
# (TunerInternal pid=1180) ╭───────────────────────────────╮
# (TunerInternal pid=1180) │ Training result               │
# (TunerInternal pid=1180) ├───────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name           │
# (TunerInternal pid=1180) │ time_this_iter_s      0.43149 │
# (TunerInternal pid=1180) │ time_total_s          50.9791 │
# (TunerInternal pid=1180) │ training_iteration        100 │
# (TunerInternal pid=1180) │ train-error           0.38466 │
# (TunerInternal pid=1180) │ train-logloss         0.65479 │
# (TunerInternal pid=1180) │ valid-error            0.3883 │
# (TunerInternal pid=1180) │ valid-logloss         0.65843 │
# (TunerInternal pid=1180) ╰───────────────────────────────╯
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training finished iteration 101 at 2024-04-13 03:15:47. Total running time: 52s
# (TunerInternal pid=1180) ╭─────────────────────────────────────────╮
# (TunerInternal pid=1180) │ Training result                         │
# (TunerInternal pid=1180) ├─────────────────────────────────────────┤
# (TunerInternal pid=1180) │ checkpoint_dir_name   checkpoint_000000 │
# (TunerInternal pid=1180) │ time_this_iter_s                0.03355 │
# (TunerInternal pid=1180) │ time_total_s                   51.01265 │
# (TunerInternal pid=1180) │ training_iteration                  101 │
# (TunerInternal pid=1180) │ train-error                     0.38466 │
# (TunerInternal pid=1180) │ train-logloss                   0.65479 │
# (TunerInternal pid=1180) │ valid-error                      0.3883 │
# (TunerInternal pid=1180) │ valid-logloss                   0.65843 │
# (TunerInternal pid=1180) ╰─────────────────────────────────────────╯
# (TunerInternal pid=1180) Training saved a checkpoint for iteration 101 at: (local)/home/ray/ray_results/XGBoostTrainer_2024-04-13_03-14-51/XGBoostTrainer_ab0d8_00000_0_2024-04-13_03-14-54/checkpoint_000000
# (TunerInternal pid=1180)
# (TunerInternal pid=1180) Training completed after 101 iterations at 2024-04-13 03:15:47. Total running time: 52s
# (TunerInternal pid=1180)
# (XGBoostTrainer pid=1311) [RayXGBoost] Finished XGBoost training on training data with total N=1,893,432 in 51.27 seconds (48.23 pure XGBoost training time).
# (XGBoostTrainer pid=1311) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/home/ray/ray_results/XGBoostTrainer_2024-04-13_03-14-51/XGBoostTrainer_ab0d8_00000_0_2024-04-13_03-14-54/checkpoint_000000)

# %% [markdown]
# ## Load and prepare data with Ray Datasets

# %% [markdown]
# ### Read Parquet file to Ray Dataset

# %%
dataset = ray.data.read_parquet(
    "s3://anyscale-training-data/intro-to-ray-air/nyc_taxi_2021.parquet"
)
# Out:
# 2024-04-13 10:13:08,897	INFO read_api.py:406 -- To satisfy the requested parallelism of 147, each read task output is split into 147 smaller blocks.

# %% [markdown]
# Returned `dataset` is [Ray Dataset](https://docs.ray.io/en/latest/data/api/doc/ray.data.Dataset.html#ray-data-dataset) - standard way to load and exchange data in Ray AI Runtime.
#
# In AIR, Datasets are used extensively for data loading and transformation. They are meant as a last-mile bridge from ETL pipeline outputs to distributed applications and libraries in Ray.

# %% [markdown]
# ### Split data into training and validation subsets

# %%
train_dataset, valid_dataset = dataset.train_test_split(test_size=0.3)
# Out:
# Read progress 0:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Split datasets into blocks for parallel preprocessing

# %%
train_dataset = train_dataset.repartition(num_blocks=3)
valid_dataset = valid_dataset.repartition(num_blocks=3)

# %% [markdown]
# `num_blocks` should be lower than number of cores in the cluster

# %% [markdown]
# ### Define a preprocessor to normalize the columns by their range

# %%
preprocessor = MinMaxScaler(columns=["trip_distance", "trip_duration"])

# %% [markdown]
# [Preprocessors](https://docs.ray.io/en/latest/ray-air/key-concepts.html#preprocessors) are primitives that transform input data into features. They operate on Datasets, making them scalable and compatible with a variety of datasources and dataframe libraries.
#
# Ray AI Runtime comes with a collection of built-in preprocessors, and you can also define your own with simple templates (see [Using preprocessors](https://docs.ray.io/en/latest/ray-air/preprocessors.html) for more information).

# %% [markdown]
# ## Train the model with Ray Train

# %% [markdown]
# |<img src="https://technical-training-assets.s3.us-west-2.amazonaws.com/Scaling_model_training/data_parallelism.png" width="50%" loading="lazy">|
# |:--|
# |Ray Train provides distributed data parallel training capabilities. A large dataset is sharded across multiple worker nodes each containing a model copy. Gradients calculated on independent nodes are continuously synchronized with others to produce a final trained model.|

# %% [markdown]
# ### Create XGBoost trainer

# %%
import ray
from ray import train
from ray.train import ScalingConfig
from ray.train.torch import TorchTrainer

from ray.train.torch import prepare_model

trainer = XGBoostTrainer(
    label_column="is_big_tip",
    num_boost_round=100,
    scaling_config=ScalingConfig(
        # Number of workers to use for data parallelism.
        num_workers=2,
        # Whether to use GPU acceleration. Set to True to schedule GPU workers.
        use_gpu=True,
    ),
    params={
        "objective": "binary:logistic",
        "eval_metric": ["logloss", "error"],
        "tree_method": "approx",  # use "gpu_hist" for GPU training
    },
    datasets={"train": train_dataset, "valid": valid_dataset},
    # preprocessor=None,
)

# def train_loop_per_worker():
#     # Get an iterator to the dataset we passed in below.
#     it = train.get_dataset_shard("train")
#     for _ in range(2):
#         # Prefetch 10 batches at a time.
#         for batch in it.iter_batches(batch_size=128, prefetch_batches=10):
#              print("Do some training on batch", batch)


# trainer = TorchTrainer(
#     train_loop_per_worker=train_loop_per_worker,
#     train_loop_config={"batch_size": 200},
#     # datasets={"train": train_dataset},
#     datasets={"train": train_dataset, "valid": valid_dataset},
#     scaling_config = ScalingConfig(
#             num_workers=2,
#             use_gpu=True,
#             resources_per_worker={"GPU": 1}
#     )
# )

# %% [markdown]
# During training, `trainer` will use `num_blocks` workers, defined when repartitioning dataset.
#
# Ray AI Runtime comes with built-in integrations with mang popular ML projects like PyTorch, Keras, LightGBM and more. Refer to the [Ray Train docs](https://docs.ray.io/en/latest/train/train.html#quick-start-to-distributed-training-with-ray-train) for more details. Optionally, read more about the Ray-XGBoost integration in the [Introducing Distributed XGBoost Training with Ray](https://www.anyscale.com/blog/distributed-xgboost-training-with-ray) blog post.

# %% [markdown]
# ### Invoke training - this is computationally intensive operation

# %%
result = trainer.fit()

# %% [markdown]
# The resulting object grants access to metrics, checkpoints, and errors

# %% [markdown]
# ### Report results

# %%
print(f"train acc = {1 - result.metrics['train-error']:.4f}")
print(f"valid acc = {1 - result.metrics['valid-error']:.4f}")
print(f"iteration = {result.metrics['training_iteration']}")
# Out:
# train acc = 0.6153
# valid acc = 0.6117
# iteration = 101

# %% [markdown]
# ## Shutdown Ray runtime

# %%
ray.shutdown()

# %% [markdown]
# Disconnect the worker and terminate processes started by `ray.init()`.

# %% [markdown]
# # Connect with the Ray community
#
# You can learn and get more involved with the Ray community of developers and researchers:
#
# * [**Ray documentation**](https://docs.ray.io/en/latest)
#
# * [**Official Ray site**](https://www.ray.io/)
# Browse the ecosystem and use this site as a hub to get the information that you need to get going and building with Ray.
#
# * [**Join the community on Slack**](https://forms.gle/9TSdDYUgxYs8SA9e8)
# Find friends to discuss your new learnings in our Slack space.
#
# * [**Use the discussion board**](https://discuss.ray.io/)
# Ask questions, follow topics, and view announcements on this community forum.
#
# * [**Join a meetup group**](https://www.meetup.com/Bay-Area-Ray-Meetup/)
# Tune in on meet-ups to listen to compelling talks, get to know other users, and meet the team behind Ray.
#
# * [**Open an issue**](https://github.com/ray-project/ray/issues/new/choose)
# Ray is constantly evolving to improve developer experience. Submit feature requests, bug-reports, and get help via GitHub issues.
#
# * [**Become a Ray contributor**](https://docs.ray.io/en/latest/ray-contribute/getting-involved.html)
# We welcome community contributions to improve our documentation and Ray framework.

# %% [markdown]
# <img src="https://technical-training-assets.s3.us-west-2.amazonaws.com/Generic/ray_logo.png" width="20%" loading="lazy">
